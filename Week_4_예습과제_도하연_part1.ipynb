# %% [markdown]
# ## 5. GBM

# %%
import pandas as pd

def get_new_feature_name_df(old_feature_name_df):
    feature_dup_df = pd.DataFrame(data=old_feature_name_df.groupby('column_name').cumcount(),
                                  columns=['dup_cnt'])
    feature_dup_df = feature_dup_df.reset_index()
    new_feature_name_df = pd.merge(old_feature_name_df.reset_index(), feature_dup_df, how='outer')
    new_feature_name_df['column_name'] = new_feature_name_df[['column_name', 'dup_cnt']].apply(lambda x : x[0]+'_'+str(x[1])
                                                                                         if x[1] >0 else x[0] ,  axis=1)
    new_feature_name_df = new_feature_name_df.drop(['index'], axis=1)
    return new_feature_name_df

# %%
import pandas as pd

def get_human_dataset( ):

    # 각 데이터 파일들은 공백으로 분리되어 있으므로 read_csv에서 공백 문자를 sep으로 할당.
    feature_name_df = pd.read_csv('./human_activity/features.txt',sep='\s+',
                        header=None,names=['column_index','column_name'])

    # 중복된 피처명을 수정하는 get_new_feature_name_df()를 이용, 신규 피처명 DataFrame생성.
    new_feature_name_df = get_new_feature_name_df(feature_name_df)

    # DataFrame에 피처명을 컬럼으로 부여하기 위해 리스트 객체로 다시 변환
    feature_name = new_feature_name_df.iloc[:, 1].values.tolist()

    # 학습 피처 데이터 셋과 테스트 피처 데이터을 DataFrame으로 로딩. 컬럼명은 feature_name 적용
    X_train = pd.read_csv('./human_activity/train/X_train.txt',sep='\s+', names=feature_name )
    X_test = pd.read_csv('./human_activity/test/X_test.txt',sep='\s+', names=feature_name)

    # 학습 레이블과 테스트 레이블 데이터을 DataFrame으로 로딩하고 컬럼명은 action으로 부여
    y_train = pd.read_csv('./human_activity/train/y_train.txt',sep='\s+',header=None,names=['action'])
    y_test = pd.read_csv('./human_activity/test/y_test.txt',sep='\s+',header=None,names=['action'])

    # 로드된 학습/테스트용 DataFrame을 모두 반환
    return X_train, X_test, y_train, y_test

# %%
# from sklearn.ensemble import GradientBoostingClassifier
# from sklearn.metrics import accuracy_score
# import pandas as pd
# import time
# import warnings
# warnings.filterwarnings('ignore')

# X_train, X_test, y_train, y_test = get_human_dataset()

# # GBM 수행 시간 측정을 위함. 시작 시간 설정.
# start_time = time.time()

# gb_clf = GradientBoostingClassifier(random_state=0)
# gb_clf.fit(X_train , y_train)
# gb_pred = gb_clf.predict(X_test)
# gb_accuracy = accuracy_score(y_test, gb_pred)

# print('GBM 정확도: {0:.4f}'.format(gb_accuracy))
# print("GBM 수행 시간: {0:.1f} 초 ".format(time.time() - start_time))

# %%
# from sklearn.model_selection import GridSearchCV

# params = {
#     'n_estimators':[100, 500],
#     'learning_rate' : [ 0.05, 0.1]
# }
# grid_cv = GridSearchCV(gb_clf , param_grid=params , cv=2 ,verbose=1)
# grid_cv.fit(X_train , y_train)
# print('최적 하이퍼 파라미터:\n', grid_cv.best_params_)
# print('최고 예측 정확도: {0:.4f}'.format(grid_cv.best_score_))

# %%
# # GridSearchCV를 이용하여 최적으로 학습된 estimator로 predict 수행.
# gb_pred = grid_cv.best_estimator_.predict(X_test)
# gb_accuracy = accuracy_score(y_test, gb_pred)
# print('GBM 정확도: {0:.4f}'.format(gb_accuracy))

# %% [markdown]
# 시간이 오래 걸려 교재에서 참고한 실행 결과만 적어둡니다.
# GBM 정확도: 0.9376
# GBM 수행 시간: 160.2 초

# %% [markdown]
# 최적 하이퍼 파라미터:
#  {'learning_rate': 0.05, 'n_estimators': 500}
# 최고 예측 정확도: 0.9010

# %% [markdown]
# GBM 정확도: 0.9410

# %% [markdown]
# ## 6. XGBoost

# %%
import xgboost as xgb
from xgboost import XGBClassifier

print(xgb.__version__)
# Out:
# 2.0.3

# %%
import xgboost as xgb
from xgboost import plot_importance
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

dataset = load_breast_cancer()
X_features= dataset.data
y_label = dataset.target

cancer_df = pd.DataFrame(data=X_features, columns=dataset.feature_names)
cancer_df['target']= y_label
cancer_df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53            152.5      1709.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
#
# [3 rows x 31 columns]

# %%
print(dataset.target_names)
print(cancer_df['target'].value_counts())
# Out:
# ['malignant' 'benign']
# 1    357
# 0    212
# Name: target, dtype: int64

# %%
# 전체 데이터 중 80%는 학습용 데이터, 20% 는 테스트용 데이터
X_train, X_test, y_train, y_test=train_test_split(X_features, y_label, test_size=0.2, random_state=156)
print(X_train.shape, X_test.shape)
# Out:
# (455, 30) (114, 30)

# %%
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test , label=y_test)

# %%
params = { 'max_depth':3,
          'eta': 0.05,
          'objective':'binary:logistic',
          'eval_metric':'logloss'
         }
num_rounds = 400

# %%
# train 데이터 세트는 'train', evaluation(test) 데이터 세트는 'eval' 로 명기합니다.
wlist=[(dtrain, 'train'), (dtest, 'eval')]
# 하이퍼 파라미터와 early stopping 파라미터를 train( ) 함수의 파라미터로 전달
xgb_model = xgb.train(params = params , dtrain=dtrain , num_boost_round=num_rounds , evals=wlist )
# Out:
# [0]	train-logloss:0.62426	eval-logloss:0.60106
# [1]	train-logloss:0.58713	eval-logloss:0.56772
# [2]	train-logloss:0.55266	eval-logloss:0.53654
# [3]	train-logloss:0.52195	eval-logloss:0.50918
# [4]	train-logloss:0.49388	eval-logloss:0.48410
# [5]	train-logloss:0.46811	eval-logloss:0.46140
# [6]	train-logloss:0.44354	eval-logloss:0.44036
# [7]	train-logloss:0.42062	eval-logloss:0.41998
# [8]	train-logloss:0.39954	eval-logloss:0.40203
# [9]	train-logloss:0.38001	eval-logloss:0.38574
# [10]	train-logloss:0.36148	eval-logloss:0.36901
# [11]	train-logloss:0.34447	eval-logloss:0.35444
# [12]	train-logloss:0.32837	eval-logloss:0.34027
# [13]	train-logloss:0.31350	eval-logloss:0.32782
# [14]	train-logloss:0.29962	eval-logloss:0.31627
# [15]	train-logloss:0.28626	eval-logloss:0.30426
# [16]	train-logloss:0.27402	eval-logloss:0.29423
# [17]	train-logloss:0.26223	eval-logloss:0.28323
# [18]	train-logloss:0.25136	eval-logloss:0.27462
# [19]	train-logloss:0.24107	eval-logloss:0.26556
# [20]	train-logloss:0.23116	eval-logloss:0.25656
# [21]	train-logloss:0.22200	eval-logloss:0.24955
# [22]	train-logloss:0.21316	eval-logloss:0.24152
# [23]	train-logloss:0.20496	eval-logloss:0.23494
# [24]	train-logloss:0.19703	eval-logloss:0.22751
# [25]	train-logloss:0.18969	eval-logloss:0.22210
# [26]	train-logloss:0.18272	eval-logloss:0.21597
# [27]	train-logloss:0.17622	eval-logloss:0.21021
# [28]	train-logloss:0.16992	eval-logloss:0.20533
# [29]	train-logloss:0.16394	eval-logloss:0.19966
# [30]	train-logloss:0.15815	eval-logloss:0.19534
# [31]	train-logloss:0.15243	eval-logloss:0.18924
# [32]	train-logloss:0.14700	eval-logloss:0.18459
# [33]	train-logloss:0.14200	eval-logloss:0.18021
# [34]	train-logloss:0.13729	eval-logloss:0.17624
# [35]	train-logloss:0.13291	eval-logloss:0.17327
# [36]	train-logloss:0.12864	eval-logloss:0.16955
# [37]	train-logloss:0.12431	eval-logloss:0.16592
# [38]	train-logloss:0.12034	eval-logloss:0.16239
# [39]	train-logloss:0.11640	eval-logloss:0.15785
# [40]	train-logloss:0.11280	eval-logloss:0.15470
# [41]	train-logloss:0.10923	eval-logloss:0.15158
# [42]	train-logloss:0.10606	eval-logloss:0.14900
# [43]	train-logloss:0.10283	eval-logloss:0.14634
# [44]	train-logloss:0.09971	eval-logloss:0.14249
# [45]	train-logloss:0.09687	eval-logloss:0.14006
# [46]	train-logloss:0.09399	eval-logloss:0.13723
# [47]	train-logloss:0.09120	eval-logloss:0.13419
# [48]	train-logloss:0.08858	eval-logloss:0.13230
# [49]	train-logloss:0.08614	eval-logloss:0.12905
# [50]	train-logloss:0.08374	eval-logloss:0.12742
# [51]	train-logloss:0.08140	eval-logloss:0.12482
# [52]	train-logloss:0.07921	eval-logloss:0.12341
# [53]	train-logloss:0.07734	eval-logloss:0.12184
# [54]	train-logloss:0.07521	eval-logloss:0.11919
# [55]	train-logloss:0.07329	eval-logloss:0.11806
# [56]	train-logloss:0.07131	eval-logloss:0.11586
# [57]	train-logloss:0.06943	eval-logloss:0.11417
# [58]	train-logloss:0.06760	eval-logloss:0.11302
# [59]	train-logloss:0.06587	eval-logloss:0.11107
# [60]	train-logloss:0.06423	eval-logloss:0.10956
# [61]	train-logloss:0.06272	eval-logloss:0.10831
# [62]	train-logloss:0.06137	eval-logloss:0.10766
# [63]	train-logloss:0.05994	eval-logloss:0.10633
# [64]	train-logloss:0.05851	eval-logloss:0.10502
# [65]	train-logloss:0.05722	eval-logloss:0.10411
# [66]	train-logloss:0.05591	eval-logloss:0.10291
# [67]	train-logloss:0.05468	eval-logloss:0.10199
# [68]	train-logloss:0.05358	eval-logloss:0.10111
# [69]	train-logloss:0.05217	eval-logloss:0.10023
# [70]	train-logloss:0.05089	eval-logloss:0.10055
# [71]	train-logloss:0.04993	eval-logloss:0.10023
# [72]	train-logloss:0.04890	eval-logloss:0.09934
# [73]	train-logloss:0.04787	eval-logloss:0.09834
# [74]	train-logloss:0.04693	eval-logloss:0.09753
# [75]	train-logloss:0.04593	eval-logloss:0.09608
# [76]	train-logloss:0.04514	eval-logloss:0.09577
# [77]	train-logloss:0.04407	eval-logloss:0.09626
# [78]	train-logloss:0.04332	eval-logloss:0.09613
# [79]	train-logloss:0.04246	eval-logloss:0.09501
# [80]	train-logloss:0.04169	eval-logloss:0.09436
# [81]	train-logloss:0.04096	eval-logloss:0.09375
# [82]	train-logloss:0.04022	eval-logloss:0.09302
# [83]	train-logloss:0.03945	eval-logloss:0.09274
# [84]	train-logloss:0.03878	eval-logloss:0.09253
# [85]	train-logloss:0.03812	eval-logloss:0.09262
# [86]	train-logloss:0.03741	eval-logloss:0.09269
# [87]	train-logloss:0.03673	eval-logloss:0.09191
# [88]	train-logloss:0.03595	eval-logloss:0.09193
# [89]	train-logloss:0.03525	eval-logloss:0.09163
# [90]	train-logloss:0.03464	eval-logloss:0.09079
# [91]	train-logloss:0.03410	eval-logloss:0.09067
# [92]	train-logloss:0.03350	eval-logloss:0.09027
# [93]	train-logloss:0.03295	eval-logloss:0.08927
# [94]	train-logloss:0.03227	eval-logloss:0.08996
# [95]	train-logloss:0.03172	eval-logloss:0.09013
# [96]	train-logloss:0.03119	eval-logloss:0.08980
# [97]	train-logloss:0.03066	eval-logloss:0.09042
# [98]	train-logloss:0.03021	eval-logloss:0.09034
# [99]	train-logloss:0.02972	eval-logloss:0.09024
# [100]	train-logloss:0.02918	eval-logloss:0.08986
# [101]	train-logloss:0.02873	eval-logloss:0.08915
# [102]	train-logloss:0.02818	eval-logloss:0.08979
# [103]	train-logloss:0.02773	eval-logloss:0.09001
# [104]	train-logloss:0.02722	eval-logloss:0.08989
# [105]	train-logloss:0.02685	eval-logloss:0.08986
# [106]	train-logloss:0.02647	eval-logloss:0.08928
# [107]	train-logloss:0.02607	eval-logloss:0.08925
# [108]	train-logloss:0.02563	eval-logloss:0.08916
# [109]	train-logloss:0.02525	eval-logloss:0.08855
# [110]	train-logloss:0.02487	eval-logloss:0.08927
# [111]	train-logloss:0.02447	eval-logloss:0.08899
# [112]	train-logloss:0.02410	eval-logloss:0.08896
# [113]	train-logloss:0.02380	eval-logloss:0.08846
# [114]	train-logloss:0.02349	eval-logloss:0.08854
# [115]	train-logloss:0.02316	eval-logloss:0.08881
# [116]	train-logloss:0.02287	eval-logloss:0.08858
# [117]	train-logloss:0.02251	eval-logloss:0.08813
# [118]	train-logloss:0.02223	eval-logloss:0.08855
# [119]	train-logloss:0.02189	eval-logloss:0.08812
# [120]	train-logloss:0.02159	eval-logloss:0.08876
# [121]	train-logloss:0.02128	eval-logloss:0.08858
# [122]	train-logloss:0.02100	eval-logloss:0.08806
# [123]	train-logloss:0.02071	eval-logloss:0.08808
# [124]	train-logloss:0.02042	eval-logloss:0.08798
# [125]	train-logloss:0.02016	eval-logloss:0.08771
# [126]	train-logloss:0.01992	eval-logloss:0.08753
# [127]	train-logloss:0.01967	eval-logloss:0.08709
# [128]	train-logloss:0.01945	eval-logloss:0.08676
# [129]	train-logloss:0.01921	eval-logloss:0.08677
# [130]	train-logloss:0.01897	eval-logloss:0.08633
# [131]	train-logloss:0.01876	eval-logloss:0.08676
# [132]	train-logloss:0.01854	eval-logloss:0.08635
# [133]	train-logloss:0.01830	eval-logloss:0.08650
# [134]	train-logloss:0.01808	eval-logloss:0.08596
# [135]	train-logloss:0.01790	eval-logloss:0.08595
# [136]	train-logloss:0.01777	eval-logloss:0.08584
# [137]	train-logloss:0.01757	eval-logloss:0.08607
# [138]	train-logloss:0.01740	eval-logloss:0.08581
# [139]	train-logloss:0.01727	eval-logloss:0.08565
# [140]	train-logloss:0.01710	eval-logloss:0.08626
# [141]	train-logloss:0.01693	eval-logloss:0.08618
# [142]	train-logloss:0.01677	eval-logloss:0.08610
# [143]	train-logloss:0.01657	eval-logloss:0.08627
# [144]	train-logloss:0.01640	eval-logloss:0.08684
# [145]	train-logloss:0.01623	eval-logloss:0.08642
# [146]	train-logloss:0.01609	eval-logloss:0.08667
# [147]	train-logloss:0.01595	eval-logloss:0.08660
# [148]	train-logloss:0.01582	eval-logloss:0.08658
# [149]	train-logloss:0.01566	eval-logloss:0.08711
# [150]	train-logloss:0.01552	eval-logloss:0.08702
# [151]	train-logloss:0.01540	eval-logloss:0.08695
# [152]	train-logloss:0.01525	eval-logloss:0.08714
# [153]	train-logloss:0.01517	eval-logloss:0.08693
# [154]	train-logloss:0.01507	eval-logloss:0.08662
# [155]	train-logloss:0.01491	eval-logloss:0.08631
# [156]	train-logloss:0.01478	eval-logloss:0.08652
# [157]	train-logloss:0.01466	eval-logloss:0.08676
# [158]	train-logloss:0.01457	eval-logloss:0.08665
# [159]	train-logloss:0.01448	eval-logloss:0.08656
# [160]	train-logloss:0.01431	eval-logloss:0.08673
# [161]	train-logloss:0.01420	eval-logloss:0.08680
# [162]	train-logloss:0.01410	eval-logloss:0.08689
# [163]	train-logloss:0.01400	eval-logloss:0.08696
# [164]	train-logloss:0.01388	eval-logloss:0.08698
# [165]	train-logloss:0.01381	eval-logloss:0.08664
# [166]	train-logloss:0.01369	eval-logloss:0.08636
# [167]	train-logloss:0.01359	eval-logloss:0.08627
# [168]	train-logloss:0.01349	eval-logloss:0.08636
# [169]	train-logloss:0.01342	eval-logloss:0.08626
# [170]	train-logloss:0.01329	eval-logloss:0.08590
# [171]	train-logloss:0.01322	eval-logloss:0.08562
# [172]	train-logloss:0.01311	eval-logloss:0.08582
# [173]	train-logloss:0.01301	eval-logloss:0.08589
# [174]	train-logloss:0.01291	eval-logloss:0.08562
# [175]	train-logloss:0.01283	eval-logloss:0.08575
# [176]	train-logloss:0.01277	eval-logloss:0.08549
# [177]	train-logloss:0.01267	eval-logloss:0.08569
# [178]	train-logloss:0.01258	eval-logloss:0.08576
# [179]	train-logloss:0.01248	eval-logloss:0.08551
# [180]	train-logloss:0.01241	eval-logloss:0.08543
# [181]	train-logloss:0.01235	eval-logloss:0.08534
# [182]	train-logloss:0.01227	eval-logloss:0.08542
# [183]	train-logloss:0.01217	eval-logloss:0.08541
# [184]	train-logloss:0.01210	eval-logloss:0.08548
# [185]	train-logloss:0.01205	eval-logloss:0.08520
# [186]	train-logloss:0.01196	eval-logloss:0.08497
# [187]	train-logloss:0.01190	eval-logloss:0.08488
# [188]	train-logloss:0.01182	eval-logloss:0.08496
# [189]	train-logloss:0.01176	eval-logloss:0.08488
# [190]	train-logloss:0.01168	eval-logloss:0.08488
# [191]	train-logloss:0.01162	eval-logloss:0.08501
# [192]	train-logloss:0.01155	eval-logloss:0.08509
# [193]	train-logloss:0.01149	eval-logloss:0.08516
# [194]	train-logloss:0.01141	eval-logloss:0.08516
# [195]	train-logloss:0.01135	eval-logloss:0.08509
# [196]	train-logloss:0.01129	eval-logloss:0.08503
# [197]	train-logloss:0.01123	eval-logloss:0.08503
# [198]	train-logloss:0.01115	eval-logloss:0.08554
# [199]	train-logloss:0.01109	eval-logloss:0.08549
# [200]	train-logloss:0.01103	eval-logloss:0.08542
# [201]	train-logloss:0.01098	eval-logloss:0.08535
# [202]	train-logloss:0.01091	eval-logloss:0.08513
# [203]	train-logloss:0.01086	eval-logloss:0.08487
# [204]	train-logloss:0.01081	eval-logloss:0.08481
# [205]	train-logloss:0.01074	eval-logloss:0.08484
# [206]	train-logloss:0.01068	eval-logloss:0.08479
# [207]	train-logloss:0.01061	eval-logloss:0.08525
# [208]	train-logloss:0.01056	eval-logloss:0.08520
# [209]	train-logloss:0.01051	eval-logloss:0.08515
# [210]	train-logloss:0.01044	eval-logloss:0.08495
# [211]	train-logloss:0.01039	eval-logloss:0.08494
# [212]	train-logloss:0.01033	eval-logloss:0.08538
# [213]	train-logloss:0.01028	eval-logloss:0.08540
# [214]	train-logloss:0.01023	eval-logloss:0.08534
# [215]	train-logloss:0.01019	eval-logloss:0.08529
# [216]	train-logloss:0.01014	eval-logloss:0.08524
# [217]	train-logloss:0.01007	eval-logloss:0.08505
# [218]	train-logloss:0.01003	eval-logloss:0.08531
# [219]	train-logloss:0.00999	eval-logloss:0.08532
# [220]	train-logloss:0.00993	eval-logloss:0.08575
# [221]	train-logloss:0.00989	eval-logloss:0.08569
# [222]	train-logloss:0.00985	eval-logloss:0.08565
# [223]	train-logloss:0.00981	eval-logloss:0.08565
# [224]	train-logloss:0.00975	eval-logloss:0.08567
# [225]	train-logloss:0.00972	eval-logloss:0.08554
# [226]	train-logloss:0.00968	eval-logloss:0.08557
# [227]	train-logloss:0.00963	eval-logloss:0.08583
# [228]	train-logloss:0.00959	eval-logloss:0.08577
# [229]	train-logloss:0.00955	eval-logloss:0.08592
# [230]	train-logloss:0.00953	eval-logloss:0.08594
# [231]	train-logloss:0.00949	eval-logloss:0.08620
# [232]	train-logloss:0.00944	eval-logloss:0.08645
# [233]	train-logloss:0.00940	eval-logloss:0.08621
# [234]	train-logloss:0.00937	eval-logloss:0.08608
# [235]	train-logloss:0.00933	eval-logloss:0.08604
# [236]	train-logloss:0.00930	eval-logloss:0.08585
# [237]	train-logloss:0.00925	eval-logloss:0.08568
# [238]	train-logloss:0.00921	eval-logloss:0.08563
# [239]	train-logloss:0.00918	eval-logloss:0.08560
# [240]	train-logloss:0.00916	eval-logloss:0.08562
# [241]	train-logloss:0.00911	eval-logloss:0.08604
# [242]	train-logloss:0.00907	eval-logloss:0.08608
# [243]	train-logloss:0.00906	eval-logloss:0.08605
# [244]	train-logloss:0.00902	eval-logloss:0.08602
# [245]	train-logloss:0.00899	eval-logloss:0.08579
# [246]	train-logloss:0.00894	eval-logloss:0.08604
# [247]	train-logloss:0.00890	eval-logloss:0.08600
# [248]	train-logloss:0.00887	eval-logloss:0.08596
# [249]	train-logloss:0.00884	eval-logloss:0.08576
# [250]	train-logloss:0.00879	eval-logloss:0.08578
# [251]	train-logloss:0.00877	eval-logloss:0.08575
# [252]	train-logloss:0.00873	eval-logloss:0.08600
# [253]	train-logloss:0.00870	eval-logloss:0.08581
# [254]	train-logloss:0.00867	eval-logloss:0.08568
# [255]	train-logloss:0.00863	eval-logloss:0.08570
# [256]	train-logloss:0.00861	eval-logloss:0.08567
# [257]	train-logloss:0.00858	eval-logloss:0.08549
# [258]	train-logloss:0.00854	eval-logloss:0.08573
# [259]	train-logloss:0.00852	eval-logloss:0.08566
# [260]	train-logloss:0.00851	eval-logloss:0.08563
# [261]	train-logloss:0.00848	eval-logloss:0.08545
# [262]	train-logloss:0.00844	eval-logloss:0.08570
# [263]	train-logloss:0.00839	eval-logloss:0.08571
# [264]	train-logloss:0.00837	eval-logloss:0.08553
# [265]	train-logloss:0.00834	eval-logloss:0.08542
# [266]	train-logloss:0.00831	eval-logloss:0.08520
# [267]	train-logloss:0.00830	eval-logloss:0.08518
# [268]	train-logloss:0.00826	eval-logloss:0.08542
# [269]	train-logloss:0.00823	eval-logloss:0.08525
# [270]	train-logloss:0.00822	eval-logloss:0.08517
# [271]	train-logloss:0.00820	eval-logloss:0.08515
# [272]	train-logloss:0.00817	eval-logloss:0.08503
# [273]	train-logloss:0.00814	eval-logloss:0.08505
# [274]	train-logloss:0.00811	eval-logloss:0.08488
# [275]	train-logloss:0.00807	eval-logloss:0.08490
# [276]	train-logloss:0.00806	eval-logloss:0.08482
# [277]	train-logloss:0.00803	eval-logloss:0.08470
# [278]	train-logloss:0.00799	eval-logloss:0.08498
# [279]	train-logloss:0.00798	eval-logloss:0.08496
# [280]	train-logloss:0.00797	eval-logloss:0.08488
# [281]	train-logloss:0.00795	eval-logloss:0.08472
# [282]	train-logloss:0.00791	eval-logloss:0.08510
# [283]	train-logloss:0.00790	eval-logloss:0.08497
# [284]	train-logloss:0.00786	eval-logloss:0.08500
# [285]	train-logloss:0.00785	eval-logloss:0.08492
# [286]	train-logloss:0.00784	eval-logloss:0.08490
# [287]	train-logloss:0.00782	eval-logloss:0.08476
# [288]	train-logloss:0.00781	eval-logloss:0.08474
# [289]	train-logloss:0.00777	eval-logloss:0.08511
# [290]	train-logloss:0.00775	eval-logloss:0.08495
# [291]	train-logloss:0.00772	eval-logloss:0.08532
# [292]	train-logloss:0.00771	eval-logloss:0.08520
# [293]	train-logloss:0.00770	eval-logloss:0.08518
# [294]	train-logloss:0.00769	eval-logloss:0.08511
# [295]	train-logloss:0.00766	eval-logloss:0.08547
# [296]	train-logloss:0.00763	eval-logloss:0.08560
# [297]	train-logloss:0.00762	eval-logloss:0.08563
# [298]	train-logloss:0.00760	eval-logloss:0.08562
# [299]	train-logloss:0.00759	eval-logloss:0.08553
# [300]	train-logloss:0.00757	eval-logloss:0.08553
# [301]	train-logloss:0.00756	eval-logloss:0.08541
# [302]	train-logloss:0.00755	eval-logloss:0.08540
# [303]	train-logloss:0.00754	eval-logloss:0.08533
# [304]	train-logloss:0.00753	eval-logloss:0.08533
# [305]	train-logloss:0.00751	eval-logloss:0.08526
# [306]	train-logloss:0.00750	eval-logloss:0.08524
# [307]	train-logloss:0.00749	eval-logloss:0.08512
# [308]	train-logloss:0.00748	eval-logloss:0.08513
# [309]	train-logloss:0.00747	eval-logloss:0.08499
# [310]	train-logloss:0.00746	eval-logloss:0.08498
# [311]	train-logloss:0.00745	eval-logloss:0.08501
# [312]	train-logloss:0.00744	eval-logloss:0.08502
# [313]	train-logloss:0.00741	eval-logloss:0.08515
# [314]	train-logloss:0.00740	eval-logloss:0.08503
# [315]	train-logloss:0.00739	eval-logloss:0.08502
# [316]	train-logloss:0.00738	eval-logloss:0.08489
# [317]	train-logloss:0.00737	eval-logloss:0.08489
# [318]	train-logloss:0.00736	eval-logloss:0.08492
# [319]	train-logloss:0.00734	eval-logloss:0.08491
# [320]	train-logloss:0.00733	eval-logloss:0.08492
# [321]	train-logloss:0.00732	eval-logloss:0.08479
# [322]	train-logloss:0.00731	eval-logloss:0.08485
# [323]	train-logloss:0.00730	eval-logloss:0.08474
# [324]	train-logloss:0.00729	eval-logloss:0.08474
# [325]	train-logloss:0.00728	eval-logloss:0.08475
# [326]	train-logloss:0.00727	eval-logloss:0.08462
# [327]	train-logloss:0.00726	eval-logloss:0.08463
# [328]	train-logloss:0.00725	eval-logloss:0.08462
# [329]	train-logloss:0.00724	eval-logloss:0.08450
# [330]	train-logloss:0.00723	eval-logloss:0.08444
# [331]	train-logloss:0.00722	eval-logloss:0.08450
# [332]	train-logloss:0.00721	eval-logloss:0.08451
# [333]	train-logloss:0.00720	eval-logloss:0.08438
# [334]	train-logloss:0.00719	eval-logloss:0.08437
# [335]	train-logloss:0.00718	eval-logloss:0.08426
# [336]	train-logloss:0.00717	eval-logloss:0.08427
# [337]	train-logloss:0.00716	eval-logloss:0.08429
# [338]	train-logloss:0.00716	eval-logloss:0.08430
# [339]	train-logloss:0.00715	eval-logloss:0.08417
# [340]	train-logloss:0.00714	eval-logloss:0.08418
# [341]	train-logloss:0.00713	eval-logloss:0.08418
# [342]	train-logloss:0.00712	eval-logloss:0.08406
# [343]	train-logloss:0.00711	eval-logloss:0.08400
# [344]	train-logloss:0.00710	eval-logloss:0.08395
# [345]	train-logloss:0.00709	eval-logloss:0.08395
# [346]	train-logloss:0.00708	eval-logloss:0.08398
# [347]	train-logloss:0.00707	eval-logloss:0.08399
# [348]	train-logloss:0.00706	eval-logloss:0.08386
# [349]	train-logloss:0.00705	eval-logloss:0.08386
# [350]	train-logloss:0.00704	eval-logloss:0.08381
# [351]	train-logloss:0.00703	eval-logloss:0.08370
# [352]	train-logloss:0.00702	eval-logloss:0.08371
# [353]	train-logloss:0.00702	eval-logloss:0.08377
# [354]	train-logloss:0.00701	eval-logloss:0.08380
# [355]	train-logloss:0.00700	eval-logloss:0.08379
# [356]	train-logloss:0.00699	eval-logloss:0.08373
# [357]	train-logloss:0.00698	eval-logloss:0.08360
# [358]	train-logloss:0.00697	eval-logloss:0.08361
# [359]	train-logloss:0.00696	eval-logloss:0.08361
# [360]	train-logloss:0.00695	eval-logloss:0.08350
# [361]	train-logloss:0.00694	eval-logloss:0.08351
# [362]	train-logloss:0.00694	eval-logloss:0.08339
# [363]	train-logloss:0.00693	eval-logloss:0.08340
# [364]	train-logloss:0.00692	eval-logloss:0.08335
# [365]	train-logloss:0.00691	eval-logloss:0.08337
# [366]	train-logloss:0.00690	eval-logloss:0.08338
# [367]	train-logloss:0.00689	eval-logloss:0.08339
# [368]	train-logloss:0.00688	eval-logloss:0.08327
# [369]	train-logloss:0.00688	eval-logloss:0.08316
# [370]	train-logloss:0.00687	eval-logloss:0.08316
# [371]	train-logloss:0.00686	eval-logloss:0.08310
# [372]	train-logloss:0.00685	eval-logloss:0.08312
# [373]	train-logloss:0.00684	eval-logloss:0.08318
# [374]	train-logloss:0.00683	eval-logloss:0.08319
# [375]	train-logloss:0.00682	eval-logloss:0.08308
# [376]	train-logloss:0.00682	eval-logloss:0.08308
# [377]	train-logloss:0.00681	eval-logloss:0.08296
# [378]	train-logloss:0.00680	eval-logloss:0.08297
# [379]	train-logloss:0.00679	eval-logloss:0.08300
# [380]	train-logloss:0.00678	eval-logloss:0.08301
# [381]	train-logloss:0.00677	eval-logloss:0.08296
# [382]	train-logloss:0.00677	eval-logloss:0.08287
# [383]	train-logloss:0.00676	eval-logloss:0.08281
# [384]	train-logloss:0.00675	eval-logloss:0.08281
# [385]	train-logloss:0.00674	eval-logloss:0.08282
# [386]	train-logloss:0.00673	eval-logloss:0.08272
# [387]	train-logloss:0.00673	eval-logloss:0.08278
# [388]	train-logloss:0.00672	eval-logloss:0.08279
# [389]	train-logloss:0.00671	eval-logloss:0.08282
# [390]	train-logloss:0.00670	eval-logloss:0.08282
# [391]	train-logloss:0.00669	eval-logloss:0.08284
# [392]	train-logloss:0.00669	eval-logloss:0.08273
# [393]	train-logloss:0.00668	eval-logloss:0.08280
# [394]	train-logloss:0.00667	eval-logloss:0.08281
# [395]	train-logloss:0.00666	eval-logloss:0.08277
# [396]	train-logloss:0.00666	eval-logloss:0.08272
# [397]	train-logloss:0.00665	eval-logloss:0.08263
# [398]	train-logloss:0.00664	eval-logloss:0.08264
# [399]	train-logloss:0.00663	eval-logloss:0.08267

# %%
pred_probs = xgb_model.predict(dtest)
print('predict( ) 수행 결과값을 10개만 표시, 예측 확률 값으로 표시됨')
print(np.round(pred_probs[:10],3))

# 예측 확률이 0.5 보다 크면 1 , 그렇지 않으면 0 으로 예측값 결정하여 List 객체인 preds에 저장
preds = [ 1 if x > 0.5 else 0 for x in pred_probs ]
print('예측값 10개만 표시:',preds[:10])
# Out:
# predict( ) 수행 결과값을 10개만 표시, 예측 확률 값으로 표시됨
# [0.884 0.003 0.899 0.187 0.992 1.    1.    0.999 0.995 0.   ]
# 예측값 10개만 표시: [1, 0, 1, 0, 1, 1, 1, 1, 1, 0]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
get_clf_eval(y_test, preds, pred_probs)
# Out:
# 오차 행렬
# [[35  2]
#  [ 1 76]]
# 정확도: 0.9737, 정밀도: 0.9744, 재현율: 0.9870,    F1: 0.9806, AUC:0.9954

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(xgb_model, ax=ax)
plt.savefig('p239_xgb_feature_importance.tif', format='tif', dpi=300, bbox_inches='tight')

# %%
# 사이킷런 래퍼 XGBoost 클래스인 XGBClassifier 임포트
from xgboost import XGBClassifier

xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3)
xgb_wrapper.fit(X_train, y_train)
w_preds = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

# %%
get_clf_eval(y_test , w_preds, w_pred_proba)
# Out:
# 오차 행렬
# [[35  2]
#  [ 1 76]]
# 정확도: 0.9737, 정밀도: 0.9744, 재현율: 0.9870,    F1: 0.9806, AUC:0.9947

# %%
from xgboost import XGBClassifier

xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3)
evals = [(X_test, y_test)]
xgb_wrapper.fit(X_train, y_train, early_stopping_rounds=100, eval_metric="logloss",
                eval_set=evals, verbose=True)

ws100_preds = xgb_wrapper.predict(X_test)
ws100_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
# Out:
# [0]	validation_0-logloss:0.56554
# [1]	validation_0-logloss:0.50669
# [2]	validation_0-logloss:0.45868
# [3]	validation_0-logloss:0.41822
# [4]	validation_0-logloss:0.38103
# [5]	validation_0-logloss:0.35137
# [6]	validation_0-logloss:0.32588
# [7]	validation_0-logloss:0.30127
# [8]	validation_0-logloss:0.28197
# [9]	validation_0-logloss:0.26265
# [10]	validation_0-logloss:0.24821
# [11]	validation_0-logloss:0.23231
# [12]	validation_0-logloss:0.22079
# [13]	validation_0-logloss:0.20795
# [14]	validation_0-logloss:0.19764
# [15]	validation_0-logloss:0.18950
# [16]	validation_0-logloss:0.18052
# [17]	validation_0-logloss:0.17246
# [18]	validation_0-logloss:0.16512
# [19]	validation_0-logloss:0.15828
# [20]	validation_0-logloss:0.15436
# [21]	validation_0-logloss:0.14633
# [22]	validation_0-logloss:0.13936
# [23]	validation_0-logloss:0.13393
# [24]	validation_0-logloss:0.13015
# [25]	validation_0-logloss:0.12489
# [26]	validation_0-logloss:0.12206
# [27]	validation_0-logloss:0.11890
# [28]	validation_0-logloss:0.11637
# [29]	validation_0-logloss:0.11293
# [30]	validation_0-logloss:0.11040
# [31]	validation_0-logloss:0.10826
# [32]	validation_0-logloss:0.10452
# [33]	validation_0-logloss:0.10322
# [34]	validation_0-logloss:0.10059
# [35]	validation_0-logloss:0.09869
# [36]	validation_0-logloss:0.09658
# [37]	validation_0-logloss:0.09487
# [38]	validation_0-logloss:0.09443
# [39]	validation_0-logloss:0.09374
# [40]	validation_0-logloss:0.09239
# [41]	validation_0-logloss:0.09159
# [42]	validation_0-logloss:0.09004
# [43]	validation_0-logloss:0.09029
# [44]	validation_0-logloss:0.08966
# [45]	validation_0-logloss:0.08808
# [46]	validation_0-logloss:0.08783
# [47]	validation_0-logloss:0.08756
# [48]	validation_0-logloss:0.08682
# [49]	validation_0-logloss:0.08829
# [50]	validation_0-logloss:0.08882
# [51]	validation_0-logloss:0.08871
# [52]	validation_0-logloss:0.08780
# [53]	validation_0-logloss:0.08766
# [54]	validation_0-logloss:0.08825
# [55]	validation_0-logloss:0.08882
# [56]	validation_0-logloss:0.08785
# [57]	validation_0-logloss:0.08813
# [58]	validation_0-logloss:0.08871
# [59]	validation_0-logloss:0.08760
# [60]	validation_0-logloss:0.08712
# [61]	validation_0-logloss:0.08795
# [62]	validation_0-logloss:0.08799
# [63]	validation_0-logloss:0.08808
# [64]	validation_0-logloss:0.08749
# [65]	validation_0-logloss:0.08760
# [66]	validation_0-logloss:0.08708
# [67]	validation_0-logloss:0.08668
# [68]	validation_0-logloss:0.08654
# [69]	validation_0-logloss:0.08630
# [70]	validation_0-logloss:0.08574
# [71]	validation_0-logloss:0.08696
# [72]	validation_0-logloss:0.08626
# [73]	validation_0-logloss:0.08685
# [74]	validation_0-logloss:0.08663
# [75]	validation_0-logloss:0.08780
# [76]	validation_0-logloss:0.08713
# [77]	validation_0-logloss:0.08822
# [78]	validation_0-logloss:0.08758
# [79]	validation_0-logloss:0.08728
# [80]	validation_0-logloss:0.08703
# [81]	validation_0-logloss:0.08719
# [82]	validation_0-logloss:0.08662
# [83]	validation_0-logloss:0.08637
# [84]	validation_0-logloss:0.08570
# [85]	validation_0-logloss:0.08590
# [86]	validation_0-logloss:0.08587
# [87]	validation_0-logloss:0.08614
# [88]	validation_0-logloss:0.08635
# [89]	validation_0-logloss:0.08646
# [90]	validation_0-logloss:0.08583
# [91]	validation_0-logloss:0.08583
# [92]	validation_0-logloss:0.08564
# [93]	validation_0-logloss:0.08669
# [94]	validation_0-logloss:0.08692
# [95]	validation_0-logloss:0.08687
# [96]	validation_0-logloss:0.08641
# [97]	validation_0-logloss:0.08584
# [98]	validation_0-logloss:0.08568
# [99]	validation_0-logloss:0.08552
# [100]	validation_0-logloss:0.08548
# [101]	validation_0-logloss:0.08630
# [102]	validation_0-logloss:0.08658
# [103]	validation_0-logloss:0.08656
# [104]	validation_0-logloss:0.08742
# [105]	validation_0-logloss:0.08779
# [106]	validation_0-logloss:0.08777
# [107]	validation_0-logloss:0.08738
# [108]	validation_0-logloss:0.08729
# [109]	validation_0-logloss:0.08736
# [110]	validation_0-logloss:0.08722
# [111]	validation_0-logloss:0.08774
# [112]	validation_0-logloss:0.08864
# [113]	validation_0-logloss:0.08871
# [114]	validation_0-logloss:0.08836
# [115]	validation_0-logloss:0.08865
# [116]	validation_0-logloss:0.08874
# [117]	validation_0-logloss:0.08861
# [118]	validation_0-logloss:0.08819
# [119]	validation_0-logloss:0.08901
# [120]	validation_0-logloss:0.08894
# [121]	validation_0-logloss:0.08869
# [122]	validation_0-logloss:0.08880
# [123]	validation_0-logloss:0.08848
# [124]	validation_0-logloss:0.08858
# [125]	validation_0-logloss:0.08849
# [126]	validation_0-logloss:0.08909
# [127]	validation_0-logloss:0.08886
# [128]	validation_0-logloss:0.08861
# [129]	validation_0-logloss:0.08942
# [130]	validation_0-logloss:0.08934
# [131]	validation_0-logloss:0.08918
# [132]	validation_0-logloss:0.08880
# [133]	validation_0-logloss:0.08956
# [134]	validation_0-logloss:0.08949
# [135]	validation_0-logloss:0.08934
# [136]	validation_0-logloss:0.08891
# [137]	validation_0-logloss:0.08949
# [138]	validation_0-logloss:0.08962
# [139]	validation_0-logloss:0.08969
# [140]	validation_0-logloss:0.08963
# [141]	validation_0-logloss:0.08948
# [142]	validation_0-logloss:0.08961
# [143]	validation_0-logloss:0.09038
# [144]	validation_0-logloss:0.09033
# [145]	validation_0-logloss:0.08991
# [146]	validation_0-logloss:0.08955
# [147]	validation_0-logloss:0.08994
# [148]	validation_0-logloss:0.09002
# [149]	validation_0-logloss:0.09004
# [150]	validation_0-logloss:0.09000
# [151]	validation_0-logloss:0.08985
# [152]	validation_0-logloss:0.08947
# [153]	validation_0-logloss:0.08979
# [154]	validation_0-logloss:0.09010
# [155]	validation_0-logloss:0.09022
# [156]	validation_0-logloss:0.09018
# [157]	validation_0-logloss:0.08997
# [158]	validation_0-logloss:0.09000
# [159]	validation_0-logloss:0.08977
# [160]	validation_0-logloss:0.08976
# [161]	validation_0-logloss:0.08985
# [162]	validation_0-logloss:0.08988
# [163]	validation_0-logloss:0.08959
# [164]	validation_0-logloss:0.08955
# [165]	validation_0-logloss:0.08958
# [166]	validation_0-logloss:0.08930
# [167]	validation_0-logloss:0.08926
# [168]	validation_0-logloss:0.08913
# [169]	validation_0-logloss:0.08915
# [170]	validation_0-logloss:0.08893
# [171]	validation_0-logloss:0.08896
# [172]	validation_0-logloss:0.08908
# [173]	validation_0-logloss:0.08886
# [174]	validation_0-logloss:0.08886
# [175]	validation_0-logloss:0.08895
# [176]	validation_0-logloss:0.08899
# [177]	validation_0-logloss:0.08895
# [178]	validation_0-logloss:0.08867
# [179]	validation_0-logloss:0.08856
# [180]	validation_0-logloss:0.08844
# [181]	validation_0-logloss:0.08841
# [182]	validation_0-logloss:0.08849
# [183]	validation_0-logloss:0.08853
# [184]	validation_0-logloss:0.08831
# [185]	validation_0-logloss:0.08843
# [186]	validation_0-logloss:0.08847
# [187]	validation_0-logloss:0.08826
# [188]	validation_0-logloss:0.08827
# [189]	validation_0-logloss:0.08817
# [190]	validation_0-logloss:0.08826
# [191]	validation_0-logloss:0.08823
# [192]	validation_0-logloss:0.08811
# [193]	validation_0-logloss:0.08791
# [194]	validation_0-logloss:0.08795
# [195]	validation_0-logloss:0.08806
# [196]	validation_0-logloss:0.08787
# [197]	validation_0-logloss:0.08790
# [198]	validation_0-logloss:0.08792
# [199]	validation_0-logloss:0.08800

# %%
get_clf_eval(y_test , ws100_preds, ws100_pred_proba)
# Out:
# 오차 행렬
# [[34  3]
#  [ 1 76]]
# 정확도: 0.9649, 정밀도: 0.9620, 재현율: 0.9870,    F1: 0.9744, AUC:0.9951

# %%
# early_stopping_rounds를 10으로 설정하고 재 학습.
xgb_wrapper.fit(X_train, y_train, early_stopping_rounds=10,
                eval_metric="logloss", eval_set=evals,verbose=True)

ws10_preds = xgb_wrapper.predict(X_test)
ws10_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
get_clf_eval(y_test , ws10_preds, ws10_pred_proba)
# Out:
# [0]	validation_0-logloss:0.56554
# [1]	validation_0-logloss:0.50669
# [2]	validation_0-logloss:0.45868
# [3]	validation_0-logloss:0.41822
# [4]	validation_0-logloss:0.38103
# [5]	validation_0-logloss:0.35137
# [6]	validation_0-logloss:0.32588
# [7]	validation_0-logloss:0.30127
# [8]	validation_0-logloss:0.28197
# [9]	validation_0-logloss:0.26265
# [10]	validation_0-logloss:0.24821
# [11]	validation_0-logloss:0.23231
# [12]	validation_0-logloss:0.22079
# [13]	validation_0-logloss:0.20795
# [14]	validation_0-logloss:0.19764
# [15]	validation_0-logloss:0.18950
# [16]	validation_0-logloss:0.18052
# [17]	validation_0-logloss:0.17246
# [18]	validation_0-logloss:0.16512
# [19]	validation_0-logloss:0.15828
# [20]	validation_0-logloss:0.15436
# [21]	validation_0-logloss:0.14633
# [22]	validation_0-logloss:0.13936
# [23]	validation_0-logloss:0.13393
# [24]	validation_0-logloss:0.13015
# [25]	validation_0-logloss:0.12489
# [26]	validation_0-logloss:0.12206
# [27]	validation_0-logloss:0.11890
# [28]	validation_0-logloss:0.11637
# [29]	validation_0-logloss:0.11293
# [30]	validation_0-logloss:0.11040
# [31]	validation_0-logloss:0.10826
# [32]	validation_0-logloss:0.10452
# [33]	validation_0-logloss:0.10322
# [34]	validation_0-logloss:0.10059
# [35]	validation_0-logloss:0.09869
# [36]	validation_0-logloss:0.09658
# [37]	validation_0-logloss:0.09487
# [38]	validation_0-logloss:0.09443
# [39]	validation_0-logloss:0.09374
# [40]	validation_0-logloss:0.09239
# [41]	validation_0-logloss:0.09159
# [42]	validation_0-logloss:0.09004
# [43]	validation_0-logloss:0.09029
# [44]	validation_0-logloss:0.08966
# [45]	validation_0-logloss:0.08808
# [46]	validation_0-logloss:0.08783
# [47]	validation_0-logloss:0.08756
# [48]	validation_0-logloss:0.08682
# [49]	validation_0-logloss:0.08829
# [50]	validation_0-logloss:0.08882
# [51]	validation_0-logloss:0.08871
# [52]	validation_0-logloss:0.08780
# [53]	validation_0-logloss:0.08766
# [54]	validation_0-logloss:0.08825
# [55]	validation_0-logloss:0.08882
# [56]	validation_0-logloss:0.08785
# [57]	validation_0-logloss:0.08813
# [58]	validation_0-logloss:0.08871
# 오차 행렬
# [[34  3]
#  [ 2 75]]
# 정확도: 0.9561, 정밀도: 0.9615, 재현율: 0.9740,    F1: 0.9677, AUC:0.9954

# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
# 사이킷런 래퍼 클래스를 입력해도 무방.
plot_importance(xgb_wrapper, ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ## 7. LightGBM

# %% [markdown]
# lightgbm 다운그레이드에 문제가 있어 별도 파일로 제출하겠습니다.

# %% [markdown]
# ## 10. 스태킹 앙상블

# %%
import numpy as np

from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

cancer_data = load_breast_cancer()

X_data = cancer_data.data
y_label = cancer_data.target

X_train , X_test , y_train , y_test = train_test_split(X_data , y_label , test_size=0.2 , random_state=0)

# %%
# 개별 ML 모델을 위한 Classifier 생성.
knn_clf  = KNeighborsClassifier(n_neighbors=4)
rf_clf = RandomForestClassifier(n_estimators=100, random_state=0)
dt_clf = DecisionTreeClassifier()
ada_clf = AdaBoostClassifier(n_estimators=100)

# 최종 Stacking 모델을 위한 Classifier생성.
lr_final = LogisticRegression(C=10)

# %%
# 개별 모델들을 학습.
knn_clf.fit(X_train, y_train)
rf_clf.fit(X_train , y_train)
dt_clf.fit(X_train , y_train)
ada_clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
# 학습된 개별 모델들이 각자 반환하는 예측 데이터 셋을 생성하고 개별 모델의 정확도 측정.
knn_pred = knn_clf.predict(X_test)
rf_pred = rf_clf.predict(X_test)
dt_pred = dt_clf.predict(X_test)
ada_pred = ada_clf.predict(X_test)

print('KNN 정확도: {0:.4f}'.format(accuracy_score(y_test, knn_pred)))
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy_score(y_test, rf_pred)))
print('결정 트리 정확도: {0:.4f}'.format(accuracy_score(y_test, dt_pred)))
print('에이다부스트 정확도: {0:.4f} :'.format(accuracy_score(y_test, ada_pred)))
# Out:
# KNN 정확도: 0.9211
# 랜덤 포레스트 정확도: 0.9649
# 결정 트리 정확도: 0.9123
# 에이다부스트 정확도: 0.9561 :

# %%
pred = np.array([knn_pred, rf_pred, dt_pred, ada_pred])
print(pred.shape)

# transpose를 이용해 행과 열의 위치 교환. 컬럼 레벨로 각 알고리즘의 예측 결과를 피처로 만듦.
pred = np.transpose(pred)
print(pred.shape)
# Out:
# (4, 114)
# (114, 4)

# %%
lr_final.fit(pred, y_test)
final = lr_final.predict(pred)

print('최종 메타 모델의 예측 정확도: {0:.4f}'.format(accuracy_score(y_test , final)))
# Out:
# 최종 메타 모델의 예측 정확도: 0.9649

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error

# 개별 기반 모델에서 최종 메타 모델이 사용할 학습 및 테스트용 데이터를 생성하기 위한 함수.
def get_stacking_base_datasets(model, X_train_n, y_train_n, X_test_n, n_folds ):
    # 지정된 n_folds값으로 KFold 생성.
    kf = KFold(n_splits=n_folds, shuffle=False)
    #추후에 메타 모델이 사용할 학습 데이터 반환을 위한 넘파이 배열 초기화
    train_fold_pred = np.zeros((X_train_n.shape[0] ,1 ))
    test_pred = np.zeros((X_test_n.shape[0],n_folds))
    print(model.__class__.__name__ , ' model 시작 ')

    for folder_counter , (train_index, valid_index) in enumerate(kf.split(X_train_n)):
        #입력된 학습 데이터에서 기반 모델이 학습/예측할 폴드 데이터 셋 추출
        print('\t 폴드 세트: ',folder_counter,' 시작 ')
        X_tr = X_train_n[train_index]
        y_tr = y_train_n[train_index]
        X_te = X_train_n[valid_index]

        #폴드 세트 내부에서 다시 만들어진 학습 데이터로 기반 모델의 학습 수행.
        model.fit(X_tr , y_tr)
        #폴드 세트 내부에서 다시 만들어진 검증 데이터로 기반 모델 예측 후 데이터 저장.
        train_fold_pred[valid_index, :] = model.predict(X_te).reshape(-1,1)
        #입력된 원본 테스트 데이터를 폴드 세트내 학습된 기반 모델에서 예측 후 데이터 저장.
        test_pred[:, folder_counter] = model.predict(X_test_n)

    # 폴드 세트 내에서 원본 테스트 데이터를 예측한 데이터를 평균하여 테스트 데이터로 생성
    test_pred_mean = np.mean(test_pred, axis=1).reshape(-1,1)

    #train_fold_pred는 최종 메타 모델이 사용하는 학습 데이터, test_pred_mean은 테스트 데이터
    return train_fold_pred , test_pred_mean

# %%
knn_train, knn_test = get_stacking_base_datasets(knn_clf, X_train, y_train, X_test, 7)
rf_train, rf_test = get_stacking_base_datasets(rf_clf, X_train, y_train, X_test, 7)
dt_train, dt_test = get_stacking_base_datasets(dt_clf, X_train, y_train, X_test,  7)
ada_train, ada_test = get_stacking_base_datasets(ada_clf, X_train, y_train, X_test, 7)
# Out:
# KNeighborsClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# RandomForestClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# DecisionTreeClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작
# AdaBoostClassifier  model 시작
# 	 폴드 세트:  0  시작
# 	 폴드 세트:  1  시작
# 	 폴드 세트:  2  시작
# 	 폴드 세트:  3  시작
# 	 폴드 세트:  4  시작
# 	 폴드 세트:  5  시작
# 	 폴드 세트:  6  시작

# %%
Stack_final_X_train = np.concatenate((knn_train, rf_train, dt_train, ada_train), axis=1)
Stack_final_X_test = np.concatenate((knn_test, rf_test, dt_test, ada_test), axis=1)
print('원본 학습 피처 데이터 Shape:',X_train.shape, '원본 테스트 피처 Shape:',X_test.shape)
print('스태킹 학습 피처 데이터 Shape:', Stack_final_X_train.shape,
      '스태킹 테스트 피처 데이터 Shape:',Stack_final_X_test.shape)
# Out:
# 원본 학습 피처 데이터 Shape: (455, 30) 원본 테스트 피처 Shape: (114, 30)
# 스태킹 학습 피처 데이터 Shape: (455, 4) 스태킹 테스트 피처 데이터 Shape: (114, 4)

# %%
lr_final.fit(Stack_final_X_train, y_train)
stack_final = lr_final.predict(Stack_final_X_test)

print('최종 메타 모델의 예측 정확도: {0:.4f}'.format(accuracy_score(y_test, stack_final)))
# Out:
# 최종 메타 모델의 예측 정확도: 0.9737

# %% [markdown]
# ## 4.8 하이퍼 파라미터 튜닝

# %%
import hyperopt

print(hyperopt.__version__)
# Out:
# 0.2.7

# %%
from hyperopt import hp

# -10 ~ 10까지 1간격을 가지는 입력 변수 x와 -15 ~ 15까지 1간격으로 입력 변수 y 설정.
search_space = {'x': hp.quniform('x', -10, 10, 1), 'y': hp.quniform('y', -15, 15, 1) }

# %%
from hyperopt import STATUS_OK

# 목적 함수를 생성. 변숫값과 변수 검색 공간을 가지는 딕셔너리를 인자로 받고, 특정 값을 반환
def objective_func(search_space):
    x = search_space['x']
    y = search_space['y']
    retval = x**2 - 20*y

    return retval

# %%
from hyperopt import fmin, tpe, Trials
import numpy as np

# 입력 결괏값을 저장한 Trials 객체값 생성.
trial_val = Trials()

# 목적 함수의 최솟값을 반환하는 최적 입력 변숫값을 5번의 입력값 시도(max_evals=5)로 찾아냄.
best_01 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=5
               , trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_01)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 445.86trial/s, best loss: -224.0]
# best: {'x': -4.0, 'y': 12.0}

# %%
trial_val = Trials()

# max_evals를 20회로 늘려서 재테스트
best_02 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=20
               , trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_02)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 707.89trial/s, best loss: -296.0]
# best: {'x': 2.0, 'y': 15.0}

# %%
# fmin( )에 인자로 들어가는 Trials 객체의 result 속성에 파이썬 리스트로 목적 함수 반환값들이 저장됨
# 리스트 내부의 개별 원소는 {'loss':함수 반환값, 'status':반환 상태값} 와 같은 딕셔너리임.
print(trial_val.results)
# Out:
# [{'loss': -64.0, 'status': 'ok'}, {'loss': -184.0, 'status': 'ok'}, {'loss': 56.0, 'status': 'ok'}, {'loss': -224.0, 'status': 'ok'}, {'loss': 61.0, 'status': 'ok'}, {'loss': -296.0, 'status': 'ok'}, {'loss': -40.0, 'status': 'ok'}, {'loss': 281.0, 'status': 'ok'}, {'loss': 64.0, 'status': 'ok'}, {'loss': 100.0, 'status': 'ok'}, {'loss': 60.0, 'status': 'ok'}, {'loss': -39.0, 'status': 'ok'}, {'loss': 1.0, 'status': 'ok'}, {'loss': -164.0, 'status': 'ok'}, {'loss': 21.0, 'status': 'ok'}, {'loss': -56.0, 'status': 'ok'}, {'loss': 284.0, 'status': 'ok'}, {'loss': 176.0, 'status': 'ok'}, {'loss': -171.0, 'status': 'ok'}, {'loss': 0.0, 'status': 'ok'}]

# %%
# Trials 객체의 vals 속성에 {'입력변수명':개별 수행 시마다 입력된 값 리스트} 형태로 저장됨.
print(trial_val.vals)
# Out:
# {'x': [-6.0, -4.0, 4.0, -4.0, 9.0, 2.0, 10.0, -9.0, -8.0, -0.0, -0.0, 1.0, 9.0, 6.0, 9.0, 2.0, -2.0, -4.0, 7.0, -0.0], 'y': [5.0, 10.0, -2.0, 12.0, 1.0, 15.0, 7.0, -10.0, 0.0, -5.0, -3.0, 2.0, 4.0, 10.0, 3.0, 3.0, -14.0, -8.0, 11.0, -0.0]}

# %%
import pandas as pd

# results에서 loss 키값에 해당하는 밸류들을 추출하여 list로 생성.
losses = [loss_dict['loss'] for loss_dict in trial_val.results]

# DataFrame으로 생성.
result_df = pd.DataFrame({'x': trial_val.vals['x'], 'y': trial_val.vals['y'], 'losses': losses})
result_df
# Out:
#        x     y  losses
# 0   -6.0   5.0   -64.0
# 1   -4.0  10.0  -184.0
# 2    4.0  -2.0    56.0
# 3   -4.0  12.0  -224.0
# 4    9.0   1.0    61.0
# 5    2.0  15.0  -296.0
# 6   10.0   7.0   -40.0
# 7   -9.0 -10.0   281.0
# 8   -8.0   0.0    64.0
# 9   -0.0  -5.0   100.0
# 10  -0.0  -3.0    60.0
# 11   1.0   2.0   -39.0
# 12   9.0   4.0     1.0
# 13   6.0  10.0  -164.0
# 14   9.0   3.0    21.0
# 15   2.0   3.0   -56.0
# 16  -2.0 -14.0   284.0
# 17  -4.0  -8.0   176.0
# 18   7.0  11.0  -171.0
# 19  -0.0  -0.0     0.0

# %%
# 아래 코드는 이전에 수록된 코드라 책에는 싣지 않았습니다.
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

dataset = load_breast_cancer()

cancer_df = pd.DataFrame(data=dataset.data, columns=dataset.feature_names)
cancer_df['target']= dataset.target
X_features = cancer_df.iloc[:, :-1]
y_label = cancer_df.iloc[:, -1]

# %%
# 전체 데이터 중 80%는 학습용 데이터, 20%는 테스트용 데이터 추출
X_train, X_test, y_train, y_test=train_test_split(X_features, y_label, test_size=0.2, random_state=156 )

# 앞에서 추출한 학습 데이터를 다시 학습과 검증 데이터로 분리
X_tr, X_val, y_tr, y_val= train_test_split(X_train, y_train, test_size=0.1, random_state=156 )

# %%
from hyperopt import hp

# max_depth는 5에서 20까지 1간격으로, min_child_weight는 1에서 2까지 1간격으로
# colsample_bytree는 0.5에서 1사이, learning_rate는 0.01에서 0.2 사이 정규 분포된 값으로 검색.
xgb_search_space = {'max_depth': hp.quniform('max_depth', 5, 20, 1),
                    'min_child_weight': hp.quniform('min_child_weight', 1, 2, 1),
                    'learning_rate': hp.uniform('learning_rate', 0.01, 0.2),
                    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1),
                   }

# %%
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from hyperopt import STATUS_OK

# fmin()에서 입력된 search_space 값으로 입력된 모든 값은 실수형임.
# XGBClassifier의 정수형 하이퍼 파라미터는 정수형 변환을 해줘야 함.
# 정확도는 높을수록 더 좋은 수치임. -1 * 정확도를 곱해서 큰 정확도 값일수록 최소가 되도록 변환
def objective_func(search_space):
    # 수행 시간 절약을 위해 nestimators는 100으로 축소
    xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                            min_child_weight=int(search_space['min_child_weight']),
                            learning_rate=search_space['learning_rate'],
                            colsample_bytree=search_space['colsample_bytree'],
                            eval_metric='logloss')
    accuracy = cross_val_score(xgb_clf, X_train, y_train, scoring='accuracy', cv=3)

    # accuracy는 cv=3 개수만큼 roc-auc 결과를 리스트로 가짐. 이를 평균해서 반환하되 -1을 곱함.
    return {'loss':-1 * np.mean(accuracy), 'status': STATUS_OK}

# %%
from hyperopt import fmin, tpe, Trials

trial_val = Trials()
best = fmin(fn=objective_func,
            space=xgb_search_space,
            algo=tpe.suggest,
            max_evals=50, # 최대 반복 횟수를 지정합니다.
            trials=trial_val, rstate=np.random.default_rng(seed=9))
print('best:', best)
# Out:
# 100%|██████████| 50/50 [00:26<00:00,  1.91trial/s, best loss: -0.967047170907401]
# best: {'colsample_bytree': 0.548301545497125, 'learning_rate': 0.1840281762576621, 'max_depth': 18.0, 'min_child_weight': 2.0}

# %%
print('colsample_bytree:{0}, learning_rate:{1}, max_depth:{2}, min_child_weight:{3}'.format(
    round(best['colsample_bytree'], 5), round(best['learning_rate'], 5),
    int(best['max_depth']), int(best['min_child_weight'])))
# Out:
# colsample_bytree:0.5483, learning_rate:0.18403, max_depth:18, min_child_weight:2

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
xgb_wrapper = XGBClassifier(n_estimators=400,
                            learning_rate=round(best['learning_rate'], 5),
                            max_depth=int(best['max_depth']),
                            min_child_weight=int(best['min_child_weight']),
                            colsample_bytree=round(best['colsample_bytree'], 5)
                           )

evals = [(X_tr, y_tr), (X_val, y_val)]
xgb_wrapper.fit(X_tr, y_tr, early_stopping_rounds=50, eval_metric='logloss',
                eval_set=evals, verbose=True)

preds = xgb_wrapper.predict(X_test)
pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, preds, pred_proba)
# Out:
# [0]	validation_0-logloss:0.52464	validation_1-logloss:0.55510
# [1]	validation_0-logloss:0.42441	validation_1-logloss:0.48641
# [2]	validation_0-logloss:0.35023	validation_1-logloss:0.43336
# [3]	validation_0-logloss:0.29341	validation_1-logloss:0.39157
# [4]	validation_0-logloss:0.24995	validation_1-logloss:0.35869
# [5]	validation_0-logloss:0.21406	validation_1-logloss:0.33711
# [6]	validation_0-logloss:0.18467	validation_1-logloss:0.32415
# [7]	validation_0-logloss:0.16291	validation_1-logloss:0.30830
# [8]	validation_0-logloss:0.14352	validation_1-logloss:0.29894
# [9]	validation_0-logloss:0.12620	validation_1-logloss:0.27850
# [10]	validation_0-logloss:0.11240	validation_1-logloss:0.27026
# [11]	validation_0-logloss:0.10142	validation_1-logloss:0.26501
# [12]	validation_0-logloss:0.09186	validation_1-logloss:0.26248
# [13]	validation_0-logloss:0.08452	validation_1-logloss:0.25936
# [14]	validation_0-logloss:0.07803	validation_1-logloss:0.26213
# [15]	validation_0-logloss:0.07128	validation_1-logloss:0.25470
# [16]	validation_0-logloss:0.06650	validation_1-logloss:0.25492
# [17]	validation_0-logloss:0.06266	validation_1-logloss:0.25634
# [18]	validation_0-logloss:0.05786	validation_1-logloss:0.24944
# [19]	validation_0-logloss:0.05355	validation_1-logloss:0.25036
# [20]	validation_0-logloss:0.05002	validation_1-logloss:0.24972
# [21]	validation_0-logloss:0.04654	validation_1-logloss:0.25250
# [22]	validation_0-logloss:0.04421	validation_1-logloss:0.24979
# [23]	validation_0-logloss:0.04146	validation_1-logloss:0.25044
# [24]	validation_0-logloss:0.03963	validation_1-logloss:0.24702
# [25]	validation_0-logloss:0.03782	validation_1-logloss:0.24628
# [26]	validation_0-logloss:0.03596	validation_1-logloss:0.25301
# [27]	validation_0-logloss:0.03448	validation_1-logloss:0.25432
# [28]	validation_0-logloss:0.03318	validation_1-logloss:0.25111
# [29]	validation_0-logloss:0.03193	validation_1-logloss:0.25502
# [30]	validation_0-logloss:0.03075	validation_1-logloss:0.25624
# [31]	validation_0-logloss:0.03007	validation_1-logloss:0.25443
# [32]	validation_0-logloss:0.02914	validation_1-logloss:0.24923
# [33]	validation_0-logloss:0.02822	validation_1-logloss:0.25104
# [34]	validation_0-logloss:0.02752	validation_1-logloss:0.24779
# [35]	validation_0-logloss:0.02688	validation_1-logloss:0.24102
# [36]	validation_0-logloss:0.02617	validation_1-logloss:0.24194
# [37]	validation_0-logloss:0.02563	validation_1-logloss:0.24254
# [38]	validation_0-logloss:0.02531	validation_1-logloss:0.24036
# [39]	validation_0-logloss:0.02468	validation_1-logloss:0.24150
# [40]	validation_0-logloss:0.02412	validation_1-logloss:0.24247
# [41]	validation_0-logloss:0.02388	validation_1-logloss:0.24228
# [42]	validation_0-logloss:0.02340	validation_1-logloss:0.24326
# [43]	validation_0-logloss:0.02313	validation_1-logloss:0.24130
# [44]	validation_0-logloss:0.02291	validation_1-logloss:0.24401
# [45]	validation_0-logloss:0.02270	validation_1-logloss:0.24228
# [46]	validation_0-logloss:0.02229	validation_1-logloss:0.24162
# [47]	validation_0-logloss:0.02209	validation_1-logloss:0.24141
# [48]	validation_0-logloss:0.02191	validation_1-logloss:0.24124
# [49]	validation_0-logloss:0.02174	validation_1-logloss:0.24402
# [50]	validation_0-logloss:0.02156	validation_1-logloss:0.24245
# [51]	validation_0-logloss:0.02141	validation_1-logloss:0.24211
# [52]	validation_0-logloss:0.02124	validation_1-logloss:0.24152
# [53]	validation_0-logloss:0.02105	validation_1-logloss:0.24418
# [54]	validation_0-logloss:0.02089	validation_1-logloss:0.24407
# [55]	validation_0-logloss:0.02073	validation_1-logloss:0.24652
# [56]	validation_0-logloss:0.02059	validation_1-logloss:0.24471
# [57]	validation_0-logloss:0.02043	validation_1-logloss:0.24323
# [58]	validation_0-logloss:0.02030	validation_1-logloss:0.24315
# [59]	validation_0-logloss:0.02015	validation_1-logloss:0.24556
# [60]	validation_0-logloss:0.02001	validation_1-logloss:0.24533
# [61]	validation_0-logloss:0.01987	validation_1-logloss:0.24395
# [62]	validation_0-logloss:0.01974	validation_1-logloss:0.24625
# [63]	validation_0-logloss:0.01962	validation_1-logloss:0.24322
# [64]	validation_0-logloss:0.01951	validation_1-logloss:0.24285
# [65]	validation_0-logloss:0.01940	validation_1-logloss:0.24498
# [66]	validation_0-logloss:0.01928	validation_1-logloss:0.24375
# [67]	validation_0-logloss:0.01916	validation_1-logloss:0.24089
# [68]	validation_0-logloss:0.01905	validation_1-logloss:0.24070
# [69]	validation_0-logloss:0.01894	validation_1-logloss:0.24280
# [70]	validation_0-logloss:0.01882	validation_1-logloss:0.24405
# [71]	validation_0-logloss:0.01872	validation_1-logloss:0.24282
# [72]	validation_0-logloss:0.01861	validation_1-logloss:0.24267
# [73]	validation_0-logloss:0.01851	validation_1-logloss:0.24004
# [74]	validation_0-logloss:0.01841	validation_1-logloss:0.23731
# [75]	validation_0-logloss:0.01830	validation_1-logloss:0.23855
# [76]	validation_0-logloss:0.01819	validation_1-logloss:0.23697
# [77]	validation_0-logloss:0.01809	validation_1-logloss:0.23686
# [78]	validation_0-logloss:0.01800	validation_1-logloss:0.23800
# [79]	validation_0-logloss:0.01791	validation_1-logloss:0.23649
# [80]	validation_0-logloss:0.01782	validation_1-logloss:0.23387
# [81]	validation_0-logloss:0.01773	validation_1-logloss:0.23455
# [82]	validation_0-logloss:0.01765	validation_1-logloss:0.23554
# [83]	validation_0-logloss:0.01756	validation_1-logloss:0.23549
# [84]	validation_0-logloss:0.01749	validation_1-logloss:0.23547
# [85]	validation_0-logloss:0.01741	validation_1-logloss:0.23306
# [86]	validation_0-logloss:0.01733	validation_1-logloss:0.23519
# [87]	validation_0-logloss:0.01725	validation_1-logloss:0.23495
# [88]	validation_0-logloss:0.01715	validation_1-logloss:0.23230
# [89]	validation_0-logloss:0.01708	validation_1-logloss:0.23254
# [90]	validation_0-logloss:0.01700	validation_1-logloss:0.23010
# [91]	validation_0-logloss:0.01692	validation_1-logloss:0.23116
# [92]	validation_0-logloss:0.01685	validation_1-logloss:0.23144
# [93]	validation_0-logloss:0.01677	validation_1-logloss:0.23041
# [94]	validation_0-logloss:0.01670	validation_1-logloss:0.23015
# [95]	validation_0-logloss:0.01663	validation_1-logloss:0.22892
# [96]	validation_0-logloss:0.01657	validation_1-logloss:0.22681
# [97]	validation_0-logloss:0.01649	validation_1-logloss:0.22781
# [98]	validation_0-logloss:0.01643	validation_1-logloss:0.22814
# [99]	validation_0-logloss:0.01637	validation_1-logloss:0.22606
# [100]	validation_0-logloss:0.01629	validation_1-logloss:0.22810
# [101]	validation_0-logloss:0.01623	validation_1-logloss:0.22804
# [102]	validation_0-logloss:0.01617	validation_1-logloss:0.22994
# [103]	validation_0-logloss:0.01611	validation_1-logloss:0.22778
# [104]	validation_0-logloss:0.01605	validation_1-logloss:0.22786
# [105]	validation_0-logloss:0.01599	validation_1-logloss:0.22698
# [106]	validation_0-logloss:0.01592	validation_1-logloss:0.22668
# [107]	validation_0-logloss:0.01586	validation_1-logloss:0.22561
# [108]	validation_0-logloss:0.01580	validation_1-logloss:0.22654
# [109]	validation_0-logloss:0.01575	validation_1-logloss:0.22627
# [110]	validation_0-logloss:0.01569	validation_1-logloss:0.22848
# [111]	validation_0-logloss:0.01563	validation_1-logloss:0.22754
# [112]	validation_0-logloss:0.01557	validation_1-logloss:0.22558
# [113]	validation_0-logloss:0.01552	validation_1-logloss:0.22652
# [114]	validation_0-logloss:0.01546	validation_1-logloss:0.22867
# [115]	validation_0-logloss:0.01541	validation_1-logloss:0.22783
# [116]	validation_0-logloss:0.01536	validation_1-logloss:0.22955
# [117]	validation_0-logloss:0.01531	validation_1-logloss:0.22930
# [118]	validation_0-logloss:0.01527	validation_1-logloss:0.22854
# [119]	validation_0-logloss:0.01520	validation_1-logloss:0.22893
# [120]	validation_0-logloss:0.01515	validation_1-logloss:0.22922
# [121]	validation_0-logloss:0.01510	validation_1-logloss:0.22730
# [122]	validation_0-logloss:0.01505	validation_1-logloss:0.22823
# [123]	validation_0-logloss:0.01500	validation_1-logloss:0.23017
# [124]	validation_0-logloss:0.01496	validation_1-logloss:0.22940
# [125]	validation_0-logloss:0.01491	validation_1-logloss:0.22915
# [126]	validation_0-logloss:0.01487	validation_1-logloss:0.23004
# [127]	validation_0-logloss:0.01482	validation_1-logloss:0.22827
# [128]	validation_0-logloss:0.01478	validation_1-logloss:0.22992
# [129]	validation_0-logloss:0.01473	validation_1-logloss:0.23035
# [130]	validation_0-logloss:0.01468	validation_1-logloss:0.22960
# [131]	validation_0-logloss:0.01464	validation_1-logloss:0.23000
# [132]	validation_0-logloss:0.01459	validation_1-logloss:0.22927
# [133]	validation_0-logloss:0.01455	validation_1-logloss:0.22901
# [134]	validation_0-logloss:0.01451	validation_1-logloss:0.23056
# [135]	validation_0-logloss:0.01448	validation_1-logloss:0.23096
# [136]	validation_0-logloss:0.01443	validation_1-logloss:0.23121
# [137]	validation_0-logloss:0.01439	validation_1-logloss:0.23052
# [138]	validation_0-logloss:0.01436	validation_1-logloss:0.22987
# [139]	validation_0-logloss:0.01432	validation_1-logloss:0.22962
# [140]	validation_0-logloss:0.01428	validation_1-logloss:0.23055
# [141]	validation_0-logloss:0.01424	validation_1-logloss:0.23079
# [142]	validation_0-logloss:0.01421	validation_1-logloss:0.23018
# [143]	validation_0-logloss:0.01418	validation_1-logloss:0.23058
# [144]	validation_0-logloss:0.01414	validation_1-logloss:0.23207
# [145]	validation_0-logloss:0.01410	validation_1-logloss:0.23184
# [146]	validation_0-logloss:0.01407	validation_1-logloss:0.23124
# [147]	validation_0-logloss:0.01404	validation_1-logloss:0.23164
# [148]	validation_0-logloss:0.01401	validation_1-logloss:0.23187
# [149]	validation_0-logloss:0.01397	validation_1-logloss:0.23166
# [150]	validation_0-logloss:0.01394	validation_1-logloss:0.23079
# [151]	validation_0-logloss:0.01391	validation_1-logloss:0.23224
# [152]	validation_0-logloss:0.01387	validation_1-logloss:0.23160
# [153]	validation_0-logloss:0.01384	validation_1-logloss:0.23242
# [154]	validation_0-logloss:0.01381	validation_1-logloss:0.23185
# [155]	validation_0-logloss:0.01378	validation_1-logloss:0.23164
# [156]	validation_0-logloss:0.01375	validation_1-logloss:0.23205
# [157]	validation_0-logloss:0.01372	validation_1-logloss:0.23146
# [158]	validation_0-logloss:0.01369	validation_1-logloss:0.23279
# [159]	validation_0-logloss:0.01366	validation_1-logloss:0.23260
# [160]	validation_0-logloss:0.01364	validation_1-logloss:0.23183
# [161]	validation_0-logloss:0.01361	validation_1-logloss:0.23225
# [162]	validation_0-logloss:0.01358	validation_1-logloss:0.23174
# 오차 행렬
# [[33  4]
#  [ 3 74]]
# 정확도: 0.9386, 정밀도: 0.9487, 재현율: 0.9610,    F1: 0.9548, AUC:0.9933
